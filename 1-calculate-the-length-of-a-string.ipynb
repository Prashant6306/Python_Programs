# %% [markdown]
# # **Python: Calculate the length of a string**

# %% [markdown]
# ![![image.png](attachment:cc7361f0-539b-4808-bdbc-f975b8d9288c.png)!

# %% [markdown]
# ![image.png](attachment:39a1aa50-9c01-4ef6-b24b-3b798865e38a.png)

# %%
def string_length(str1):
    count=0
    for i in str1:
        count=count+1
    return count
    
    
    
print(string_length("Jai_Ganesh"))
# Out:
# 10

# %%
print(len("Jai_Ganesh"))
# Out:
# 10
